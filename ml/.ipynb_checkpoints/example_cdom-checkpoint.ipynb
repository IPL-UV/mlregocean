# %%
# reload(cdom_processing)
import cdom_processing
from imp import reload
import numpy as np

img, band_names = cdom_processing.load_S3_image()
img.shape
# Out:
# (2369, 3329, 18)

# %%
import matplotlib
matplotlib.__version__
# Out:
# '2.1.0'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

_ = plt.hist(img[:,:,17].flatten(),bins=20)

# %%
np.min(img[:,:,16]),np.max(img[:,:,16])
# Out:
# (-3542.4685136249209, 1802.380911669238)

# %%
reload(cdom_processing)
mascara = cdom_processing.load_mask()
mascara = (mascara==1)
plt.imshow(mascara)

# %%
ratio = np.ma.masked_array(img[:,:,16],mascara)

# %%
plt.imshow(ratio,vmin=-2,vmax=3)
plt.colorbar()

# %%
np.min(img[:,:,0][mascara]),np.max(img[:,:,0][mascara])
# Out:
# (-0.063661978185395526, 0.31831572107435879)

# %%
# from scipy import sparse
# S3ratio1 = (img[:,:,7])/(img[:,:,3])
# S3ratio2 = (img[:,:,10])/(img[:,:,3])
# ratios = np.dstack(([S3ratio1, S3ratio2]))
# # print(ratios.shape, img.shape)
# img = np.dstack(([img, ratios]))
# print(img.shape)

# %%
mascara_raros = np.where((img[:,:,0] > .3) & ~mascara, 1 , 0)
plt.imshow(mascara_raros)

# %%
import pandas as pd

models = pd.read_csv("/media/ana/Nuevo vol/IPL/Databases/C2X/tabla_errores_totales_C2X.csv")
models
# Out:
#           R2                                        best_params      bias  \
# 0   0.919315                                     {'alpha': 1.0} -0.058956
# 1   0.902677                               {'n_estimators': 50} -0.036390
# 2   0.934755  {'alpha': 0.00017953321364452425, 'gamma': 327... -0.067612
# 3   0.935285  {'k1__k2': RBF(length_scale=0.105), 'k1': 6.55... -0.064054
# 4   0.926466  {'epsilon': 0.0050246206411415952, 'C': 1000.0... -0.219285
# 5   0.931047                                                 {} -0.083011
# 6   0.645953                                     {'alpha': 1.0} -0.133232
# 7   0.860464                               {'n_estimators': 10} -0.109423
# 8   0.897818  {'alpha': 1.7953321364452426e-05, 'gamma': 34.... -0.131004
# 9   0.893493  {'k1__k2': RBF(length_scale=0.01), 'k1': 11.2*... -0.141194
# 10  0.847178  {'epsilon': 5.0246206411415947e-05, 'C': 1.0, ... -0.238310
# 11  0.867831                                                 {} -0.114890
# 12  0.605217                   {'alpha': 0.0066666666666666671}  0.001150
# 13  0.991689                              {'n_estimators': 100}  0.005363
# 14  0.982734  {'alpha': 0.00017953321364452425, 'gamma': 30....  0.019407
# 15  0.995736  {'k1__k2': RBF(length_scale=[0.0114, 0.96, 2.3...  0.008527
# 16  0.891646  {'epsilon': 5.0246206411415947e-05, 'C': 1.0, ... -0.245522
# 17  0.961157                   {'alpha': 0.0058823529411764705} -0.023573
# 18  0.992552                               {'n_estimators': 50} -0.019404
# 19  0.989921  {'alpha': 1.7953321364452426e-05, 'gamma': 0.3... -0.008011
# 20  0.996477  {'k1__k2': RBF(length_scale=[1.82, 11.6, 2.15,... -0.011778
# 21  0.994761  {'epsilon': 0.0025123103205707976, 'C': 1000.0... -0.023967
# 22  0.924415                                     {'alpha': 0.5} -0.076606
# 23  0.959691                               {'n_estimators': 20} -0.078441
# 24  0.957182  {'alpha': 1.7953321364452423e-07, 'gamma': 0.4... -0.101780
# 25  0.953037  {'k1__k2': RBF(length_scale=[0.0983, 0.0438]),... -0.080638
# 26  0.956402  {'epsilon': 5.0246206411415947e-05, 'C': 100.0... -0.180530
#
#          mae    model  pearsonr   res_abs  rmse_abs  rmse_rel      name_bands
# 0   0.695042      RLR  0.958958  1.164952  1.160468  1.547494        S3ratio1
# 1   0.642467      RFR  0.950234  1.276076  1.274519  1.173286        S3ratio1
# 2   0.522930      KRR  0.967172  1.050093  1.043542  0.587062        S3ratio1
# 3   0.523347      GPR  0.967404  1.045202  1.039297  0.630510        S3ratio1
# 4   0.532597      SVR  0.965831  1.171153  1.107855  0.630825        S3ratio1
# 5   0.555561  Polyfit  0.965417  1.082384  1.072792  0.944138        S3ratio1
# 6   1.376586      RLR  0.808698  2.441833  2.430904  8.472620        S3ratio2
# 7   0.688557      RFR  0.928101  1.537813  1.526090  3.914254        S3ratio2
# 8   0.585009      KRR  0.948616  1.325513  1.305947  3.510110        S3ratio2
# 9   0.578759      GPR  0.946496  1.355538  1.333295  3.696493        S3ratio2
# 10  0.689672      SVR  0.927265  1.649571  1.597094  4.021102        S3ratio2
# 11  0.712515  Polyfit  0.932336  1.498533  1.485262  5.110502        S3ratio2
# 12  1.780839      RLR  0.780847  2.566947  2.566946  7.142399         S3bands
# 13  0.144456      RFR  0.995862  0.372569  0.372453  0.880846         S3bands
# 14  0.224310      KRR  0.991341  0.537876  0.536824  1.587883         S3bands
# 15  0.113298      GPR  0.997868  0.267172  0.266763  1.104555         S3bands
# 16  0.383154      SVR  0.951871  1.410443  1.344806  0.845307         S3bands
# 17  0.462271      RLR  0.980407  0.806220  0.805186  1.857752  S3bands&ratios
# 18  0.114181      RFR  0.996357  0.354174  0.352576  0.168328  S3bands&ratios
# 19  0.131347      KRR  0.994964  0.410392  0.410157  2.264746  S3bands&ratios
# 20  0.072156      GPR  0.998243  0.243358  0.242501  0.556523  S3bands&ratios
# 21  0.095913      SVR  0.997475  0.298607  0.295707  0.334041  S3bands&ratios
# 22  0.689196      RLR  0.961682  1.131003  1.123193  2.306124       ratios_S3
# 23  0.393303      RFR  0.980029  0.831416  0.820240  0.529144       ratios_S3
# 24  0.429505      KRR  0.979229  0.863561  0.845375  0.435228       ratios_S3
# 25  0.396960      GPR  0.976641  0.896302  0.885352  1.073279       ratios_S3
# 26  0.393418      SVR  0.980088  0.908542  0.853039  0.477338       ratios_S3

# %%
reload(cdom_processing)
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge
from sklearn.kernel_ridge import KernelRidge

relation_name_bands_bands ={"S3ratio2":["S3ratio2"],
                            "S3ratio1": ["S3ratio1"],
                           "S3bands": cdom_processing.bands_S3,
                           "S3bands&ratios":cdom_processing.bands_S3_plus_ratios}

relation_model_name_model ={"KRR":KernelRidge(kernel="rbf"),
                            "RFR": RandomForestRegressor(),
                            "RLR": Ridge()}
print(relation_name_bands_bands)
# Out:
# {'S3ratio2': ['S3ratio2'], 'S3ratio1': ['S3ratio1'], 'S3bands': ['400', '412.5', '442.5', '490', '510', '560', '620', '665', '673.75', '681.25', '708.75', '753.75', '778.75', '865', '885'], 'S3bands&ratios': ['400', '412.5', '442.5', '490', '510', '560', '620', '665', '673.75', '681.25', '708.75', '753.75', '778.75', '865', '885', 'S3ratio1', 'S3ratio2']}

# %%
from sklearn.gaussian_process.kernels import RBF, WhiteKernel, ConstantKernel
from sklearn.gaussian_process import GaussianProcessRegressor

# %%
###1. Read dataset
reload(cdom_processing)

skdata = cdom_processing.read_data_syke()

skdata.head()
# Out:
#     Unnamed: 0  Unnamed: 0.1  Run_ID   Chl   TSM  a_440_cdom   T   S  theta  \
# 0            0             0   20002  1.20  0.00       0.220  25   5     30
# 5            5             5   20032  2.10  0.08       0.218  20  20     30
# 9            9             9   20045  0.18  0.08       0.112  30   5     10
# 13          13            13   20060  0.29  1.30       0.196  15  30     20
# 16          16            16   20064  0.05  0.02       0.230   0  20     20
#
#     phi    ...       764.38     767.5    778.75       865       885       900  \
# 0    60    ...     0.000036  0.000035  0.000042  0.000015  0.000012  0.000012
# 5    15    ...     0.000043  0.000040  0.000046  0.000017  0.000015  0.000010
# 9    45    ...     0.000021  0.000020  0.000022  0.000005  0.000008  0.000007
# 13   45    ...     0.000155  0.000155  0.000167  0.000069  0.000058  0.000053
# 16   30    ...     0.000016  0.000015  0.000012  0.000005  0.000006  0.000004
#
#          940          1020  S3ratio1  S3ratio2
# 0   0.000002  1.200000e-06  0.230262  0.128128
# 5   0.000004  2.100000e-06  0.239242  0.131884
# 9   0.000001  7.000000e-07  0.125279  0.061194
# 13  0.000011  1.050000e-05  0.229513  0.121153
# 16  0.000002  0.000000e+00  0.160213  0.079574
#
# [5 rows x 41 columns]

# %%
from numpy import array

reload(cdom_processing)
indice_modelo = 20

name_bands_syke = models.loc[indice_modelo,
                                  "name_bands"]
bands_syke = relation_name_bands_bands[name_bands_syke]

name_model = models.loc[indice_modelo, "model"]
print("model %s bands: %s"%(name_model,name_bands_syke))

if name_model != "GPR":
    model = relation_model_name_model[name_model]
    params = eval(models.loc[indice_modelo,"best_params"])
    model.set_params(**params)
    print(params)
else:
    params = eval(models.loc[indice_modelo,"best_params"])
    print(params)
    kernel = params["k1"]+params["k2"]
    model = GaussianProcessRegressor(kernel=kernel,optimizer=None,n_restarts_optimizer=0)
    
scaler,y_mean = cdom_processing.load_model(skdata,model,
                                           bands=bands_syke)
model,scaler,y_mean
# Out:
# model GPR bands: S3bands&ratios
# {'k1__k2': RBF(length_scale=[1.82, 11.6, 2.15, 100, 2.46, 1.28, 0.854, 3.93, 6.3, 0.111, 5.4, 7.26, 13.6, 3.88, 37.5, 0.185, 0.33]), 'k1': 316**2 * RBF(length_scale=[1.82, 11.6, 2.15, 100, 2.46, 1.28, 0.854, 3.93, 6.3, 0.111, 5.4, 7.26, 13.6, 3.88, 37.5, 0.185, 0.33]), 'k1__k1__constant_value': 100000.00000000001, 'k1__k2__length_scale_bounds': (0.01, 100.0), 'k2': WhiteKernel(noise_level=0.0101), 'k1__k1': 99856, 'k2__noise_level_bounds': (1e-05, 10.0), 'k1__k2__length_scale': array([   1.82293654,   11.62402821,    2.15345855,  100.        ,
#           2.46398669,    1.27739223,    0.85431846,    3.92676798,
#           6.29582476,    0.1110293 ,    5.40204495,    7.2647553 ,
#          13.56842133,    3.87659071,   37.54390724,    0.18505503,
#           0.33029621]), 'k2__noise_level': 0.010059764292493145, 'k1__k1__constant_value_bounds': (1e-05, 100000.0)}
# (GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#               kernel=316**2 * RBF(length_scale=[1.82, 11.6, 2.15, 100, 2.46, 1.28, 0.854, 3.93, 6.3, 0.111, 5.4, 7.26, 13.6, 3.88, 37.5, 0.185, 0.33]) + WhiteKernel(noise_level=0.0101),
#               n_restarts_optimizer=0, normalize_y=False, optimizer=None,
#               random_state=None),
#  MinMaxScaler(copy=True, feature_range=(0, 1)),
#  3.3475602094240839)

# %%
y_mean
# Out:
# 3.3475602094240839

# %%
_ = plt.hist(skdata['a_440_cdom'])

# %%
reload(cdom_processing)
cdom_array = np.asarray(skdata['a_440_cdom'])
min_cdom = np.min(cdom_array)
max_cdom = np.max(cdom_array)
predictions = cdom_processing.predict_image(img,band_names,mascara,model,scaler,bands_syke,
                                            y_range=(0,max_cdom),y_mean=y_mean,step=300)

# %%
plt.imshow(predictions,vmax=15)
plt.colorbar()

# %%
reload(cdom_processing)
if name_model == "GPR":
    predict_function = lambda data: model.predict(data,return_std=True)[1]
    std_predictions = cdom_processing.predict_image(img,band_names,mascara,model,scaler,bands_syke,
                                                   y_range=(0,99999),y_mean=0,step=300,
                                                   predict_function=predict_function)

# %%
if name_model == "GPR":
    plt.imshow(std_predictions)
    plt.colorbar()

# %%
print("Rango cdom: %.4f %.4f"%(min_cdom,max_cdom))
# Out:
# Rango cdom: 0.0980 20.0000

# %%
_ = plt.hist(predictions[~np.isnan(predictions)],bins=100)

# %%
path = '/media/ana/Nuevo vol/IPL/Databases/'
cdom_processing.write_envi(predictions, path + name_model+'_'+name_bands_syke+'_CDOM_C2X.hdr')
# Out:
# Saving /media/ana/Nuevo vol/IPL/Databases/RFR_S3bands_CDOM_C2X.img
